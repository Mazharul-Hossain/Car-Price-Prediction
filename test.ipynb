# %%
import pandas as pd 

df = pd.read_csv('C:/Fall20/Data Mining/true_car_listings.csv')

# %%
df.head()
# Out:
#    Price  Year  Mileage              City State                Vin   Make  \
# 0   8995  2014    35725           El Paso    TX  19VDE2E53EE000083  Acura
# 1  10888  2013    19606  Long Island City    NY  19VDE1F52DE012636  Acura
# 2   8995  2013    48851           El Paso    TX  19VDE2E52DE000025  Acura
# 3  10999  2014    39922           Windsor    CO  19VDE1F71EE003817  Acura
# 4  14799  2016    22142            Lindon    UT  19UDE2F32GA001284  Acura
#
#           Model
# 0    ILX6-Speed
# 1    ILX5-Speed
# 2    ILX6-Speed
# 3    ILX5-Speed
# 4  ILXAutomatic

# %%
df.groupby("Year")["Vin"].count()
# Out:
# Year
# 1997       596
# 1998       774
# 1999      1254
# 2000      1933
# 2001      2584
# 2002      3800
# 2003      5649
# 2004      8117
# 2005     11005
# 2006     15079
# 2007     21171
# 2008     24713
# 2009     19061
# 2010     27539
# 2011     39768
# 2012     49764
# 2013     74701
# 2014    162432
# 2015    157516
# 2016    132136
# 2017     91608
# 2018       922
# Name: Vin, dtype: int64

# %%
price_data=df[df.Price<50000]

#price_data

# %%
from matplotlib import pyplot
price_data.hist(bins=100, figsize=[14,6])
#ylabel("Frequency")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000018D031D0710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000018D0435E0F0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000018D047067B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000018D04474E48>]],
#       dtype=object)
