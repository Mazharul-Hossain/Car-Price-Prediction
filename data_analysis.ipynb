# %%
import pandas as pd 
import numpy as np
import pickle
from matplotlib import pyplot as plt
import io

def price_graph():

    df = pd.read_csv('C:/Fall20/Data Mining/true_car_listings.csv')

    #df.head()
    dp=df[df['Price']<50000]
    #dp.head()
    only_price=dp['Price']
    #only_price.head()
    only_price.hist(bins=100, figsize=[14,6])

    # here is the trick save your figure into a bytes object and you can afterwards expose it via flas
    price_image = io.BytesIO()
    plt.savefig(price_image, format='png')
    price_image.seek(0)
    return price_image
#pickle.dump(histo,open('price_graph.pkl','wb'))
#ylabel("Frequency")

# %%
import pandas as pd 
import numpy as np
import pickle
from matplotlib import pyplot as plt
import io

df = pd.read_csv('C:/Fall20/Data Mining/true_car_listings.csv')
df.head(10)
# Out:
#    Price  Year  Mileage              City State                Vin   Make  \
# 0   8995  2014    35725           El Paso    TX  19VDE2E53EE000083  Acura
# 1  10888  2013    19606  Long Island City    NY  19VDE1F52DE012636  Acura
# 2   8995  2013    48851           El Paso    TX  19VDE2E52DE000025  Acura
# 3  10999  2014    39922           Windsor    CO  19VDE1F71EE003817  Acura
# 4  14799  2016    22142            Lindon    UT  19UDE2F32GA001284  Acura
# 5   7989  2012   105246             Miami    FL  JH4CU2F83CC019895  Acura
# 6  14490  2014    34032         Greatneck    NY  JH4CU2F84EC002686  Acura
# 7  13995  2013    32384       West Jordan    UT  JH4CU2F64DC006203  Acura
# 8  10495  2013    57596         Waterbury    CT  19VDE2E50DE000234  Acura
# 9   9995  2013    63887           El Paso    TX  19VDE1F50DE010450  Acura
#
#           Model
# 0    ILX6-Speed
# 1    ILX5-Speed
# 2    ILX6-Speed
# 3    ILX5-Speed
# 4  ILXAutomatic
# 5  TSXAutomatic
# 6    TSXSpecial
# ...

# %%
df[-5:]
# Out:
#         Price  Year  Mileage          City State                Vin   Make  \
# 852117  63215  2017        9   Culver City    CA  YV1A22MK9H1013237  Volvo
# 852118  72260  2017     3201     Englewood    NJ  YV4A22PL3H1186162  Volvo
# 852119  55999  2016    28941  Fort Collins    CO  YV4A22PL4G1000868  Volvo
# 852120  60240  2017     3005   San Leandro    CA  YV4A22NLXH1006162  Volvo
# 852121  76995  2017     2502      New York    NY  YV4BC0ZX1H1109845  Volvo
#
#           Model
# 852117    S90T6
# 852118   XC90T6
# 852119  XC90AWD
# 852120      V90
# 852121   XC90T8

# %%
df[df['City']=='Miami'].head()

#df.loc[:,['Year','State']]
# Out:
#      Price  Year  Mileage   City State                Vin   Make         Model
# 5     7989  2012   105246  Miami    FL  JH4CU2F83CC019895  Acura  TSXAutomatic
# 24   14999  2014    17669  Miami    FL  19VDE1F37EE015239  Acura    ILX5-Speed
# 31   14999  2015    28326  Miami    FL  19VDE1F30FE000177  Acura    ILX5-Speed
# 69   14499  2014    33363  Miami    FL  19VDE1F52EE009561  Acura    ILX5-Speed
# 354  13490  2013    52573  Miami    FL  19VDE2E59DE000331  Acura    ILX6-Speed

# %%
df['Year']>2015
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4          True
# 5         False
# 6         False
# 7         False
# 8         False
# 9         False
# 10        False
# 11        False
# 12        False
# 13        False
# 14        False
# 15        False
# 16        False
# 17        False
# 18        False
# 19        False
# 20        False
# 21        False
# 22        False
# 23        False
# 24        False
# 25        False
# 26        False
# 27        False
# 28        False
# 29        False
#           ...
# 852092     True
# 852093     True
# 852094     True
# 852095     True
# 852096     True
# 852097     True
# 852098     True
# 852099     True
# 852100     True
# 852101     True
# 852102     True
# 852103     True
# 852104     True
# 852105     True
# 852106     True
# 852107     True
# 852108     True
# 852109     True
# 852110     True
# 852111     True
# 852112     True
# 852113     True
# 852114     True
# 852115     True
# ...

# %%
year=df['Year']

year.head()
# Out:
# 0    2014
# 1    2013
# 2    2013
# 3    2014
# 4    2016
# Name: Year, dtype: int64

# %%
df.groupby("Year")["Vin"].count()
# Out:
# Year
# 1997       596
# 1998       774
# 1999      1254
# 2000      1933
# 2001      2584
# 2002      3800
# 2003      5649
# 2004      8117
# 2005     11005
# 2006     15079
# 2007     21171
# 2008     24713
# 2009     19061
# 2010     27539
# 2011     39768
# 2012     49764
# 2013     74701
# 2014    162432
# 2015    157516
# 2016    132136
# 2017     91608
# 2018       922
# Name: Vin, dtype: int64

# %%
dp=df[df['Price']<50000]
dp.head()
#price_data
# Out:
#    Price  Year  Mileage              City State                Vin   Make  \
# 0   8995  2014    35725           El Paso    TX  19VDE2E53EE000083  Acura
# 1  10888  2013    19606  Long Island City    NY  19VDE1F52DE012636  Acura
# 2   8995  2013    48851           El Paso    TX  19VDE2E52DE000025  Acura
# 3  10999  2014    39922           Windsor    CO  19VDE1F71EE003817  Acura
# 4  14799  2016    22142            Lindon    UT  19UDE2F32GA001284  Acura
#
#           Model
# 0    ILX6-Speed
# 1    ILX5-Speed
# 2    ILX6-Speed
# 3    ILX5-Speed
# 4  ILXAutomatic

# %%
only_price=dp['Price']
only_price.head()
only_price.hist(bins=100, figsize=[14,6])
plt.xlabel("X axis label")
plt.ylabel("Y axis label")
# Out:
# Text(0,0.5,'Y axis label')

# %%
df.head()
# Out:
#    Price  Year  Mileage              City State                Vin   Make  \
# 0   8995  2014    35725           El Paso    TX  19VDE2E53EE000083  Acura
# 1  10888  2013    19606  Long Island City    NY  19VDE1F52DE012636  Acura
# 2   8995  2013    48851           El Paso    TX  19VDE2E52DE000025  Acura
# 3  10999  2014    39922           Windsor    CO  19VDE1F71EE003817  Acura
# 4  14799  2016    22142            Lindon    UT  19UDE2F32GA001284  Acura
#
#           Model
# 0    ILX6-Speed
# 1    ILX5-Speed
# 2    ILX6-Speed
# 3    ILX5-Speed
# 4  ILXAutomatic

# %%
cars_by_year = df.groupby("Year")["Vin"].count()
cars_by_year.sample(10)
# Out:
# Year
# 2010     27539
# 2000      1933
# 2015    157516
# 1997       596
# 2008     24713
# 2016    132136
# 1998       774
# 2011     39768
# 2017     91608
# 2009     19061
# Name: Vin, dtype: int64

# %%
#cars_by_year.hist(bins=100, figsize=[14,6])

#groups = df.groupby(['Gender','Married']).size()
cars_by_year.plot.bar()
plt.ylabel("frequency")
# Out:
# Text(0,0.5,'frequency')

# %%
popular_cars_mask= df.groupby("Make")["Vin"].count() > 20000
popular_cars= df.groupby("Make")["Vin"].count() 
popular_cars= popular_cars.loc[popular_cars_mask]
#popular_cars = df[df.Vin.groupby(df.Make).transform('count') > 10000]
#popular_cars= df.groupby('Make').filter(lambda g: g.Vin.count() > 10000)
popular_cars.head()
#popular_cars.Make.unique()
#popular_cars.plot.bar()
#popular_cars.hist(bins=100, figsize=[14,6])
# Out:
# Make
# BMW           32415
# Chevrolet    102268
# Dodge         34368
# Ford         110432
# GMC           29008
# Name: Vin, dtype: int64

# %%
fig = plt.figure(figsize =(7, 7)) 
plt.pie(popular_cars, labels = popular_cars.index)
plt.show()

# %%
df.head()
# Out:
#    Price  Year  Mileage              City State                Vin   Make  \
# 0   8995  2014    35725           El Paso    TX  19VDE2E53EE000083  Acura
# 1  10888  2013    19606  Long Island City    NY  19VDE1F52DE012636  Acura
# 2   8995  2013    48851           El Paso    TX  19VDE2E52DE000025  Acura
# 3  10999  2014    39922           Windsor    CO  19VDE1F71EE003817  Acura
# 4  14799  2016    22142            Lindon    UT  19UDE2F32GA001284  Acura
#
#           Model
# 0    ILX6-Speed
# 1    ILX5-Speed
# 2    ILX6-Speed
# 3    ILX5-Speed
# 4  ILXAutomatic

# %%
#iris[['PetalLength']]
import pandas as pd 
import numpy as np
import pickle
from matplotlib import pyplot as plt
import io
from sklearn import linear_model

df = pd.read_csv('C:/Fall20/Data Mining/true_car_listings.csv')

linearmodel = linear_model.LinearRegression()

X=df[['Year','Mileage']]
y=df['Price']
#y.head()
linearmodel.fit(X, y)


pickle.dump(linearmodel, open('linear.pkl','wb'))

model = pickle.load(open('linear.pkl','rb'))
#print(model.predict([[4, 300, 500]]))
#y=
